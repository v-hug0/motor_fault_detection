# %% [markdown]
# Pode resolver problemas de classificação (divisões feitas por ifs) e de regressão (divisões feitas por somas dos quadrados dos erros)

# %% [markdown]
# - As divisões são feitas de forma que haja o maior ganho de informação (seja a conta ou condição)

# %% [markdown]
# - Bom por pedir pouca preparação dos dados, conseguir usar dados numéricos e categóricos, parâmetros não lineares não afetarem

# %% [markdown]
# - Ruim pelo overfitting

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn import tree

# %%
df=pd.read_csv('steel.csv')
df.head()
# Out:
#   Alloy code     C    Si    Mn      P      S     Ni    Cr    Mo    Cu    V  \
# 0        MBB  0.12  0.36  0.52  0.009  0.003  0.089  0.97  0.61  0.04  0.0
# 1        MBB  0.12  0.36  0.52  0.009  0.003  0.089  0.97  0.61  0.04  0.0
# 2        MBB  0.12  0.36  0.52  0.009  0.003  0.089  0.97  0.61  0.04  0.0
# 3        MBB  0.12  0.36  0.52  0.009  0.003  0.089  0.97  0.61  0.04  0.0
# 4        MBB  0.12  0.36  0.52  0.009  0.003  0.089  0.97  0.61  0.04  0.0
#
#       Al       N  Ceq  Nb + Ta   Temperature (°C)   0.2% Proof Stress (MPa)  \
# 0  0.003  0.0066  0.0      0.0                 27                       342
# 1  0.003  0.0066  0.0      0.0                100                       338
# 2  0.003  0.0066  0.0      0.0                200                       337
# 3  0.003  0.0066  0.0      0.0                300                       346
# 4  0.003  0.0066  0.0      0.0                400                       316
#
#     Tensile Strength (MPa)   Elongation (%)   Reduction in Area (%)
# 0                      490               30                      71
# 1                      454               27                      72
# 2                      465               23                      69
# 3                      495               21                      70
# 4                      489               26                      79

# %%
X=df.iloc[:,1:16]
X.head()
# Out:
#       C    Si    Mn      P      S     Ni    Cr    Mo    Cu    V     Al  \
# 0  0.12  0.36  0.52  0.009  0.003  0.089  0.97  0.61  0.04  0.0  0.003
# 1  0.12  0.36  0.52  0.009  0.003  0.089  0.97  0.61  0.04  0.0  0.003
# 2  0.12  0.36  0.52  0.009  0.003  0.089  0.97  0.61  0.04  0.0  0.003
# 3  0.12  0.36  0.52  0.009  0.003  0.089  0.97  0.61  0.04  0.0  0.003
# 4  0.12  0.36  0.52  0.009  0.003  0.089  0.97  0.61  0.04  0.0  0.003
#
#         N  Ceq  Nb + Ta   Temperature (°C)
# 0  0.0066  0.0      0.0                 27
# 1  0.0066  0.0      0.0                100
# 2  0.0066  0.0      0.0                200
# 3  0.0066  0.0      0.0                300
# 4  0.0066  0.0      0.0                400

# %%
y=df.iloc[:, 17]
y.head()
# Out:
# 0    490
# 1    454
# 2    465
# 3    495
# 4    489
# Name:  Tensile Strength (MPa), dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=100)

# %%
clf_entropy=DecisionTreeClassifier(criterion="entropy", random_state=100, max_depth=3, min_samples_leaf=5)
#max_depth = camadas da tree
#min_samples_leaf = minimo de leaf nodes

# %%
clf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9892/2395142735.py in <module>
# ----> 1 clf.fit(X_train, y_train)
#
# NameError: name 'clf' is not defined

# %%
y_pred = clf_entropy.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9892/1978473913.py in <module>
# ----> 1 y_pred = clf_entropy.predict(X_test)
#
# c:\users\victor\miniconda3\lib\site-packages\sklearn\tree\_classes.py in predict(self, X, check_input)
#     439             The predicted classes, or the predict values.
#     440         """
# --> 441         check_is_fitted(self)
#     442         X = self._validate_X_predict(X, check_input)
#     443         proba = self.tree_.predict(X)
#
# c:\users\victor\miniconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# c:\users\victor\miniconda3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1096
#    1097     if not attrs:
# -> 1098         raise NotFittedError(msg % {'name': type(estimator).__name__})
#    1099
#    1100
#
# NotFittedError: This DecisionTreeClassifier instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
accuracy_score(y_test, y_pred)*100
